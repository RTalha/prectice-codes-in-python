# %%
from numpy import genfromtxt
import numpy as np
import pandas as pd

# %%
matrix = genfromtxt('distt.csv', delimiter=',')
print(matrix.shape)
# Out:
# (1485, 1484)

# %%
matrix=matrix[1:,:]

# %%
matrix[1][0]
# Out:
# 0.219773

# %%
v=genfromtxt('sorted_values.csv',delimiter=',')

# %%
df3=pd.read_csv("sorted_values.csv")

# %%
dfff = pd.read_csv("dis.csv",dtype='a')
location = dfff["g1"]
print(type(location))
location1 = list(location)

uniq_clusters=list(set(location1))
cluster_indication=np.zeros((10,1483),dtype=int)
print(cluster_indication.shape)
# Out:
# <class 'pandas.core.series.Series'>
# (10, 1483)

# %%
print(v.shape)
# Out:
# (1484, 1484)

# %%
eval_values=genfromtxt('evaluation function.csv',delimiter=',')

# %%
print(eval_values.shape)
# Out:
# (7, 1484)

# %%
eval_values=eval_values[1:,:]

# %%
print(len(location1))
# Out:
# 1484

# %%
v.dtype
# Out:
# dtype('float64')

# %%
#location1
#uniq_clusters
#dist_values
#eval_values

# %%
temp=np.zeros((1484,1484),dtype=int)

# %%
eval_values[5][1]
# Out:
# 0.103923

# %%
def func(value,col):
    global temp
    global matrix
    for m in range(0,1484):
         if matrix[m][col] == value:
            print("= value",value)
            print("matrix", matrix[m][col])
            temp[m][col]=1
            break

# %%
for i in range(1,7):
    for j in range(0,1484):
        print(eval_values[i][j])
        func(eval_values[i][j],j)
# Out:
# 0.059161
# = value 0.059161
# matrix 0.059161
# 0.081854
# = value 0.081854
# matrix 0.081854
# 0.036056
# = value 0.036056
# matrix 0.036056
# 0.05
# = value 0.05
# matrix 0.05
# 0.06324600000000001
# 0.20832699999999998
# 0.054772
# = value 0.054772
# matrix 0.054772
# 0.080623
# = value 0.080623
# matrix 0.080623
# 0.04899
# = value 0.04899
# matrix 0.04899
# 0.084261
# = value 0.084261
# matrix 0.084261
# 0.055678
# = value 0.055678
# matrix 0.055678
# 0.046904
# = value 0.046904
# matrix 0.046904
# 0.084853
# = value 0.084853
# matrix 0.084853
# 0.068557
# = value 0.068557
# matrix 0.068557
# 0.086023
# = value 0.086023
# matrix 0.086023
# 0.041231
# = value 0.041231
# matrix 0.041231
# 0.075498
# = value 0.075498
# matrix 0.075498
# 0.05656900000000001
# 0.055678
# = value 0.055678
# matrix 0.055678
# 0.047958
# = value 0.047958
# matrix 0.047958
# 0.04
# = value 0.04
# matrix 0.04
# 0.057446000000000004
# 0.055678
# = value 0.055678
# matrix 0.055678
# 0.045826
# ...

# %%
np.savetxt("temp.csv", temp, delimiter=",")

# %%
dfff = pd.read_csv("dis.csv",dtype='a')
location = dfff["g1"]
print(type(location))
location1 = list(location)

uniq_clusters=list(set(location1))
cluster_indication=np.zeros((10,1483),dtype=int)
print(cluster_indication.shape)
# Out:
# <class 'pandas.core.series.Series'>
# (10, 1483)

# %%
location1[214]
# Out:
# 'CYT'

# %%
print(cluster_indication.shape)
# Out:
# (10, 1483)

# %%
print(uniq_clusters)
# Out:
# ['MIT', 'POX', 'EXC', 'NUC', 'CYT', 'ME1', 'ME3', 'ME2', 'ERL', 'VAC']
